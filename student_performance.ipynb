# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\ZYAD\Desktop\nti\machine\Student_performance_data _.csv")
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# min           0.001057     0.000000     0.000000         0.000000
# 25%           5.043079     7.000000     0.000000         1.000000
# 50%           9.705363    15.000000     0.000000         2.000000
# 75%          14.408410    22.000000     1.000000         3.000000
# max          19.978094    29.000000     1.000000         4.000000
#
#        Extracurricular       Sports        Music  Volunteering          GPA  \
# count      2392.000000  2392.000000  2392.000000   2392.000000  2392.000000
# mean          0.383361     0.303512     0.196906      0.157191     1.906186
# std           0.486307     0.459870     0.397744      0.364057     0.915156
# min           0.000000     0.000000     0.000000      0.000000     0.000000
# 25%           0.000000     0.000000     0.000000      0.000000     1.174803
# 50%           0.000000     0.000000     0.000000      0.000000     1.893393
# 75%           1.000000     1.000000     0.000000      0.000000     2.622216
# max           1.000000     1.000000     1.000000      1.000000     4.000000
#
#         GradeClass
# count  2392.000000
# mean      2.983696
# std       1.233908
# min       0.000000
# 25%       2.000000
# 50%       4.000000
# 75%       4.000000
# max       4.000000

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
l = ['Caucasian', 'African American', 'Asian', 'Other']
df['Gender'] = df['Gender'].map(lambda x:'male' if x == 0 else 'female')
df['Ethnicity'] = df['Ethnicity'].map(lambda x: l[x])
df['Tutoring'] = df['Tutoring'].map(lambda x:'Yes' if x == 1 else 'No')
df['Extracurricular'] = df['Extracurricular'].map(lambda x:'Yes' if x == 1 else 'No')
df['Sports'] = df['Sports'].map(lambda x:'Yes' if x == 1 else 'No')
df['Music'] = df['Music'].map(lambda x:'Yes' if x == 1 else 'No')
df['Volunteering'] = df['Volunteering'].map(lambda x:'Yes' if x == 1 else 'No')
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17  female  Caucasian                  2        19.833723
# 1       1002   18    male  Caucasian                  1        15.408756
# 2       1003   15    male      Asian                  3         4.210570
# 3       1004   17  female  Caucasian                  3        10.028829
# 4       1005   17  female  Caucasian                  2         4.672495
#
#    Absences Tutoring  ParentalSupport Extracurricular Sports Music  \
# 0         7      Yes                2              No     No   Yes
# 1         0       No                1              No     No    No
# 2        26       No                2              No     No    No
# 3        14       No                3             Yes     No    No
# 4        17      Yes                3              No     No    No
#
#   Volunteering       GPA  GradeClass
# 0           No  2.929196         2.0
# 1           No  3.042915         1.0
# 2           No  0.112602         4.0
# 3           No  2.054218         3.0
# 4           No  1.288061         4.0

# %%
plt.figure(figsize=(10, 6))
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
genders_with_max_gpa = df.loc[df['GPA']==df['GPA'].max(), 'Gender'].value_counts()
sns.barplot(x=genders_with_max_gpa.index, y=genders_with_max_gpa.values, palette='muted')
plt.title(f'Count of Genders with Highest GPA ({df["GPA"].max()})')
plt.show()

# %%
genders_with_max_gpa = df.loc[df['GPA']==df['GPA'].min(), 'Gender'].value_counts()
sns.barplot(x=genders_with_max_gpa.index, y=genders_with_max_gpa.values, palette='muted')
plt.title(f'Count of Genders with Lowest GPA ({df["GPA"].min()})')
plt.show()

# %%
plt.figure(figsize=(10, 6))
ethnicity_labels = ['Caucasian', 'African American', 'Asian', 'Other']
df['Ethnicity'].value_counts().sort_index().plot(kind='bar')
plt.title('Ethnicity Distribution')
plt.xlabel('Ethnicity')
plt.ylabel('Frequency')
plt.xticks(ticks=range(4), labels=ethnicity_labels)
plt.show()

# %%
plt.figure(figsize=(10, 6))
parental_education_labels = ['None', 'High School', 'Some College', "Bachelor's", 'Higher']
df['ParentalEducation'].value_counts().sort_index().plot(kind='bar')
plt.title('Parental Education Levels')
plt.xlabel('Parental Education Level')
plt.ylabel('Frequency')
plt.xticks(ticks=range(5), labels=parental_education_labels)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='StudyTimeWeekly', y='GPA', data=df)
plt.title('Study Time vs. GPA')
plt.xlabel('Weekly Study Time (hours)')
plt.ylabel('GPA')
plt.show()

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].boxplot(df['Age'])
axs[0, 0].set_title('Age')

axs[0, 1].boxplot(df['StudyTimeWeekly'])
axs[0, 1].set_title('StudyTimeWeekly')

axs[1, 0].boxplot(df['Absences'])
axs[1, 0].set_title('Absences')


fig.suptitle('Multiple subplots')
plt.tight_layout()
plt.show()

# %%
df.drop(columns=['StudentID', 'GPA'],inplace=True)
df.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17       1          0                  2        19.833723         7
# 1   18       0          0                  1        15.408756         0
# 2   15       0          2                  3         4.210570        26
# 3   17       1          0                  3        10.028829        14
# 4   17       1          0                  2         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
#
#    GradeClass
# 0         2.0
# 1         1.0
# 2         4.0
# 3         3.0
# 4         4.0

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='Age', kde=True, bins=20)
plt.title(f'Distribution of Age')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='StudyTimeWeekly', kde=True, bins=20)
plt.title(f'Distribution of StudyTimeWeekly')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='Absences', kde=True, bins=20)
plt.title(f'Distribution of Absences')
plt.show()

# %%
corr = df.corr(numeric_only=True)
corr['GradeClass'].sort_values(ascending=False)
# Out:
# GradeClass           1.000000
# Absences             0.728633
# ParentalEducation    0.041031
# Age                 -0.006250
# StudyTimeWeekly     -0.134131
# ParentalSupport     -0.136823
# Name: GradeClass, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = df.drop('GradeClass', axis=1)
y = df['GradeClass']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=df['Gender'], test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

num_cols = ['StudyTimeWeekly', 'Absences']
cat_cols = ['Sports', 'Volunteering', 'ParentalSupport', 'Music', 'Extracurricular', 'Age', 'Gender', 'Tutoring', 'Ethnicity']

cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_cols),
        ('cat', cat_transformer, cat_cols)
    ])

X_train_proccessed = preprocessor.fit_transform(X_train)
X_test_proccessed = preprocessor.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

models = {
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Logistic Regression': LogisticRegression(),
    'Support Vector Machine': SVC(),
}

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

model_names = []
accuracies = []

# Train and evaluate each model
for name, clf in models.items():
    clf.fit(X_train_proccessed, y_train)
    score = clf.score(X_test_proccessed, y_test)
    model_names.append(name)
    accuracies.append(score)
    print(f"{name} accuracy: {score:.2f}")

# Create a DataFrame for model accuracies
df_models = pd.DataFrame({'Model': model_names, 'Accuracy': accuracies})

# Plot model accuracies using Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Accuracy', data=df_models, palette='pastel')
plt.title('Model Accuracies')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.xticks(rotation=45)
plt.show()
# Out:
# Decision Tree accuracy: 0.62
# Random Forest accuracy: 0.71
# K-Nearest Neighbors accuracy: 0.62
# Logistic Regression accuracy: 0.71
#   File "c:\Users\ZYAD\anaconda3\lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#   File "c:\Users\ZYAD\anaconda3\lib\subprocess.py", line 505, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "c:\Users\ZYAD\anaconda3\lib\subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\ZYAD\anaconda3\lib\subprocess.py", line 1436, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# Support Vector Machine accuracy: 0.72

# %%
for model_name, model in models.items():
    print(f"Evaluating {model_name}...")
    y_pred = model.predict(X_test_proccessed)
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    plt.show()
# Out:
# Evaluating Decision Tree...
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.32      0.28        22
#          1.0       0.41      0.44      0.42        55
#          2.0       0.48      0.37      0.42        84
#          3.0       0.27      0.32      0.29        62
#          4.0       0.85      0.84      0.84       256
#
#     accuracy                           0.62       479
#    macro avg       0.45      0.46      0.45       479
# weighted avg       0.63      0.62      0.62       479
#
# Evaluating Random Forest...
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.23      0.33        22
#          1.0       0.52      0.42      0.46        55
#          2.0       0.54      0.56      0.55        84
#          3.0       0.45      0.45      0.45        62
#          4.0       0.86      0.93      0.89       256
#
#     accuracy                           0.71       479
#    macro avg       0.60      0.52      0.54       479
# weighted avg       0.70      0.71      0.70       479
#
# Evaluating K-Nearest Neighbors...
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.09      0.05      0.06        22
#          1.0       0.38      0.29      0.33        55
#          2.0       0.37      0.37      0.37        84
#          3.0       0.32      0.44      0.37        62
#          4.0       0.85      0.86      0.85       256
#
#     accuracy                           0.62       479
#    macro avg       0.40      0.40      0.40       479
# weighted avg       0.61      0.62      0.61       479
#
# Evaluating Logistic Regression...
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        22
#          1.0       0.51      0.53      0.52        55
#          2.0       0.58      0.52      0.55        84
#          3.0       0.46      0.53      0.49        62
#          4.0       0.87      0.92      0.89       256
#
#     accuracy                           0.71       479
#    macro avg       0.48      0.50      0.49       479
# weighted avg       0.68      0.71      0.70       479
#
# Evaluating Support Vector Machine...
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        22
#          1.0       0.51      0.47      0.49        55
#          2.0       0.58      0.58      0.58        84
#          3.0       0.47      0.60      0.53        62
#          4.0       0.88      0.91      0.89       256
#
#     accuracy                           0.72       479
#    macro avg       0.49      0.51      0.50       479
# weighted avg       0.69      0.72      0.70       479
